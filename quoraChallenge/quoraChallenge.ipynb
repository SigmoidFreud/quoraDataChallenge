# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
# parse data into csv
fl = "input00.txt"
inputdata = "input00.csv"
tst = "test.txt"
testdata = "test.csv"
output = "output00.txt"
out = "output.csv"
# data parser for input training data, and test data, and output
with open(inputdata,'r+') as inp:
    with open(fl) as f:
        for line in enumerate(f):
            if line[0] == 0:
                train_num = int(line[1].split()[0])
                continue
            elif line[0] == 1:
                inp.write(','.join(['id','score']+list(map(str, range(1,len(line[1].split())-1))))+'\n')
            else:
                inp.write(','.join(line[1].split()[:2]+[ sp.split(':')[1] for sp in line[1].split()[2:] ])+'\n')
            if line[0] == train_num:
                break
with open(testdata,'r+') as t:
    with open(tst) as f:
        for line in enumerate(f):
            if line[0] == 0:
                test_num = int(line[1].split()[0])
                continue
            elif line[0] == 1:
                t.write(','.join(['id']+list(map(str, range(1,len(line[1].split())))))+'\n')
                t.write(','.join(line[1].split()[:1]+[ sp.split(':')[1] for sp in line[1].split()[1:] ])+'\n')
            else:
                t.write(','.join(line[1].split()[:1]+[ sp.split(':')[1] for sp in line[1].split()[1:] ])+'\n')
with open(out,'r+') as o:
    with open(output) as f:
        for line in enumerate(f):
            if line[0] == 0:
                o.write("id,score"+'\n')
                o.write(','.join(line[1].split())+'\n')
            else:
                o.write(','.join(line[1].split())+'\n')
# i added the parsed data to github so it will be available through url
# inputdata = "https://raw.githubusercontent.com/SigmoidFreud/quoraDataChallenge/master/quoraChallenge/input00.csv"
# testdata = "https://raw.githubusercontent.com/SigmoidFreud/quoraDataChallenge/master/quoraChallenge/input00.csv"

# %%
df = pd.read_csv(inputdata)
# remove features 22,23 because they are the same for all answers
df = df.drop(['22','23'],axis=1)

# %%
features = df.drop(['id','score'],axis=1)

# %%
df
# Out:
#          id  score               1         2  3         4         5  \
# 0     VCaTF      1    282114466020  3.151926  1  3.737670  3.891820
# 1     gParY      1       173284955  1.785813  1  1.791759  1.945910
# 2     DtWDw      1   4708728355523  2.394989  1  3.091042  2.890372
# 3     4hUov      1      1459162488  2.002920  1  4.836282  4.158883
# 4     4VnZH     -1       747590455  1.380899  1  3.091042  2.397895
# 5     madOS      1     42438676159  0.000000  1  4.488636  3.912023
# 6     6DvWu     -1  14994168760886  1.816477  1  0.693147  1.386294
# 7     bvQwT      1   6888628852259  3.009992  1  4.744932  6.274762
# 8     Yyon1      1   5543511301254  1.714707  1  3.135494  3.295837
# 9     67JDj      1       746701980  2.591300  1  2.772589  6.259581
# 10    AlzGR      1   6961101378430  1.821645  1  4.672829  5.669881
# 11    slQXh      1       634300857  1.798752  1  4.663439  4.934474
# 12    H8Mp6     -1      1193643930  0.000000  0  0.000000  0.000000
# 13    LVIdc     -1   1143394593947  0.000000  1  6.265301  7.186144
# 14    RiH8z      1   1165699134125  3.319049  1  4.219508  4.094345
# 15    kQOe4     -1  29846045584236  0.000000  1  4.219508  4.624973
# 16    x912c     -1   1965531399827  0.000000  1  4.189655  3.526361
# 17    tmppP     -1    794866883218  0.000000  1  3.637586  4.174387
# 18    ymv87     -1   4616624265449  4.011195  1  3.951244  4.158883
# 4479   0.000000  0.000000  0.000000    ...      0   0   0   0   0   1   0   0
# 4480   0.000000  0.000000  0.000000    ...      2   1   0   0   1   0   0   0
# 4481   0.000000  0.000000  0.000000    ...      0   1   0   0   0   0   0   0
# 4482   0.000000  0.000000  0.000000    ...      4   1   0   0   1   0   0   0
# 4483  28.000000  0.000000  0.000000    ...      6   0   0   0   0   1   1   0
# 4484   0.000000  0.000000  0.000000    ...      0   0   0   1   0   0   0   0
# 4485   0.000000  0.000000  0.000000    ...      3   1   0   0   1   0   0   0
# 4486  97.000000  0.000000  0.000000    ...      0   1   0   0   1   0   0   0
# 4487  65.714286  0.000000  0.000000    ...      1   1   0   0   0   0   1   0
# 4488   0.000000  0.000000  0.000000    ...      1   1   1   0   0   0   0   0
# 4489  39.000000  0.000000  6.054043    ...      3   1   0   0   1   1   0   0
# 4490   0.000000  0.000000  0.000000    ...      1   1   0   0   1   0   0   0
# 4491   0.000000  0.000000  0.000000    ...      6   1   0   0   0   1   1   0
# 4492   0.000000  0.000000  0.000000    ...      0   1   0   1   1   0   0   0
# 4493  72.000000  0.000000  0.000000    ...      1   1   0   0   1   0   0   0
# 4494  91.666667  0.000000  0.000000    ...      0   1   0   0   1   0   0   0
# 4495   0.000000  0.000000  0.000000    ...      0   1   0   0   0   0   0   0
# 4496   0.000000  0.000000  0.000000    ...      0   0   0   0   0   0   0   0
# 4497   0.000000  0.000000  0.000000    ...      0   1   0   0   0   0   1   0
# 4498   0.000000  0.000000  0.000000    ...      6   1   0   1   0   1   0   0
#
#       20        21
# 0      2  2.890372
# 1      6  3.637586
# 2      5  2.772589
# 3      7  2.397895
# 4      2  1.791759
# 5      0  1.945910
# 6      3  2.484907
# 7      1  2.079442
# 8      3  2.772589
# 9      5  3.988984
# 10     2  1.609438
# 11     2  1.791759
# 12     1  1.386294
# 13     8  3.465736
# 14    15  5.062595
# 15     1  2.079442
# 16     4  3.044522
# 17    47  5.874931
# 18     2  2.079442
# 19    27  3.713572
# 20     3  2.772589
# 21     1  2.197225
# 22     3  1.945910
# 23     5  2.890372
# 24     7  2.302585
# 25     8  2.772589
# 26     1  2.995732
# 27     4  2.484907
# 28     3  2.484907
# 29    11  3.295837
# ...   ..       ...
# 4469   1  2.079442
# 4470  13  4.663439
# 4471   5  3.218876
# 4472  10  3.295837
# 4473  17  3.258097
# 4474   3  2.079442
# 4475   0  1.386294
# 4476   2  1.609438
# 4477   2  1.386294
# 4478   1  1.386294
# 4479   1  1.609438
# 4480   3  2.197225
# 4481  18  5.192957
# 4482   3  1.791759
# 4483  96  6.345636
# 4484   3  2.833213
# 4485   6  3.258097
# 4486   1  2.079442
# 4487   8  2.772589
# 4488   3  1.609438
# 4489   3  1.791759
# 4490  17  3.828641
# 4491   3  3.044522
# 4492   6  3.044522
# 4493  10  4.499810
# 4494   2  1.791759
# 4495   4  2.197225
# 4496   0  1.386294
# 4497  10  3.178054
# 4498  25  4.304065
#
# [4499 rows x 23 columns]

# %%
g = features.columns.to_series().groupby(features.dtypes).groups
td = {k.name: v for k, v in g.items()}

# %%
td
# Out:
# {'float64': ['2', '4', '5', '6', '7', '8', '11', '21'],
#  'int64': ['1',
#   '3',
#   '9',
#   '10',
#   '12',
#   '13',
#   '14',
#   '15',
#   '16',
#   '17',
#   '18',
#   '19',
#   '20']}

# %%
# uniformly divide positive and negative resposonses into training and test data using 80/20 cross validation rule
posdf = df[df['score'] == 1]
posdf['is_train'] = np.random.uniform(0, 1, len(posdf)) <= .8
negdf = df[df['score'] == -1]
negdf['is_train'] = np.random.uniform(0, 1, len(negdf)) <= .8
train = pd.concat([posdf[posdf['is_train'] == True],negdf[negdf['is_train'] == True]])
test = pd.concat([posdf[posdf['is_train'] == False],negdf[negdf['is_train'] == False]])
train
# Out:
#          id  score               1         2  3         4         5  \
# 2     DtWDw      1   4708728355523  2.394989  1  3.091042  2.890372
# 5     madOS      1     42438676159  0.000000  1  4.488636  3.912023
# 7     bvQwT      1   6888628852259  3.009992  1  4.744932  6.274762
# 11    slQXh      1       634300857  1.798752  1  4.663439  4.934474
# 19    QFIPm      1   1600707566246  1.960632  1  4.304065  4.262680
# 22    uFu7U      1   4535849186693  0.000000  1  3.526361  3.044522
# 28    naiXA      1   1222073882654  1.832085  1  1.791759  2.397895
# 29    dg444      1    130322514961  2.080163  1  4.442651  4.682131
# 30    uSHxh      1      1583233111  0.000000  1  4.330733  3.828641
# 31    QDF9j      1      1218328296  1.796502  0  0.000000  0.693147
# 32    FhGiq      1   1392234643950  0.000000  1  3.465736  4.369448
# 34    BQJ4K      1   6740690416683  1.715109  1  3.871201  5.459586
# 43    YgqM3      1   9016999794377  3.035392  1  1.386294  2.708050
# 47    4AlPC      1         3923270  0.000000  1  5.874931  7.052721
# 49    SYFGm      1      8222447237  1.141894  1  4.691348  4.158883
# 50    xc5mO      1   9184836987940  2.130671  1  3.988984  5.093750
# 57    FLvRQ      1    749060531835  1.308763  1  4.465908  3.988984
# 59    blDKi      1   1894440769520  1.857585  1  2.484907  1.386294
# 60    mc6j7      1   8886883404433  1.184911  1  4.488636  4.454347
# 65    a0tzG      1         8359115  1.714835  1  1.386294  2.197225
# 67    OlmmN      1  10708223086172  2.576884  1  3.258097  3.526361
# 68    b9jND      1       959012731  4.088216  1  4.997212  5.505332
# 69    WA1v0      1   3919211740762  0.000000  1  4.158883  4.262680
# 72    sYBFK      1   9953631016280  1.994433  1  4.624973  5.017280
# 74    u6RsA      1      4897610305  0.000000  1  0.000000  1.098612
# 75    tziQE      1    686042761283  1.801665  1  3.970292  4.094345
# 77    bvqQT      1    145938159890  4.382893  1  4.605170  6.302619
# 79    7WH2K      1    709442814854  3.265762  1  3.583519  4.369448
# 82    qPmb1      1   8463958341113  1.741764  1  3.526361  3.218876
# 86    ND1Sm      1   9851194116966  2.961305  1  2.995732  5.501258
# ...     ...    ...             ...       ... ..       ...       ...
# 4437  9i7zI     -1    422381458796  3.091364  1  4.477337  3.465736
# 4441  Tqrbm     -1    617111489359  2.269466  1  2.302585  2.397895
# 4442  wH2zp     -1       632293757  1.185301  1  0.693147  0.000000
# 4446  fvCOS     -1   3805143745589  2.445287  1  4.174387  4.890349
# 4448  PLbim     -1       248691220  1.869460  1  1.098612  0.000000
# 4493  72.000000  0.000000  0.000000    ...      1   0   0   1   0   0   0  10
# 4494  91.666667  0.000000  0.000000    ...      1   0   0   1   0   0   0   2
# 4495   0.000000  0.000000  0.000000    ...      1   0   0   0   0   0   0   4
# 4496   0.000000  0.000000  0.000000    ...      0   0   0   0   0   0   0   0
# 4497   0.000000  0.000000  0.000000    ...      1   0   0   0   0   1   0  10
#
#             21  is_train
# 2     2.772589      True
# 5     1.945910      True
# 7     2.079442      True
# 11    1.791759      True
# 19    3.713572      True
# 22    1.945910      True
# 28    2.484907      True
# 29    3.295837      True
# 30    2.197225      True
# 31    2.772589      True
# 32    1.386294      True
# 34    1.791759      True
# 43    2.197225      True
# 47    5.983936      True
# 49    2.833213      True
# 50    1.791759      True
# 57    5.669881      True
# 59    1.945910      True
# 60    2.079442      True
# 65    6.345636      True
# 67    1.098612      True
# 68    3.218876      True
# 69    1.609438      True
# 72    2.995732      True
# 74    2.079442      True
# 75    1.098612      True
# 77    1.386294      True
# 79    1.098612      True
# 82    3.433987      True
# 86    2.944439      True
# ...        ...       ...
# 4437  1.945910      True
# 4441  2.302585      True
# 4442  2.833213      True
# 4446  1.945910      True
# 4448  1.609438      True
# 4449  2.397895      True
# 4452  2.564949      True
# 4453  1.098612      True
# 4459  2.079442      True
# 4460  1.609438      True
# 4461  3.258097      True
# 4464  2.484907      True
# 4466  2.564949      True
# 4469  2.079442      True
# 4470  4.663439      True
# 4471  3.218876      True
# 4473  3.258097      True
# 4475  1.386294      True
# 4476  1.609438      True
# 4479  1.609438      True
# 4481  5.192957      True
# 4484  2.833213      True
# 4488  1.609438      True
# 4489  1.791759      True
# 4492  3.044522      True
# 4493  4.499810      True
# 4494  1.791759      True
# 4495  2.197225      True
# 4496  1.386294      True
# 4497  3.178054      True
#
# [3579 rows x 24 columns]

# %%
# mixed feature selection algorithm since we are clearly dealing with both continuous and categorical variables
# feature ranking algorithm implemented from http://perso.uclouvain.be/michel.verleysen/papers/kdir11gd.pdf
# elimination of features due to mixed categorical and continuous information using generic dimensionality reduction could result in severe loss of information so we will try a different approach
# we should definitely test out different types of classifiers to see which one actually performs the best
potential_classifiers = [ LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True, intercept_scaling=1, penalty='l1', random_state=None, tol=0.0001),DecisionTreeClassifier(max_depth=None, min_samples_split=1, random_state=0),RandomForestClassifier(n_estimators=10, max_depth=None, min_samples_split=1, random_state=0),ExtraTreesClassifier(n_estimators=10, max_depth=None, min_samples_split=1, random_state=0),GaussianNB(),BernoulliNB(alpha=5.0) ]
def filter_wrapper_featureselection(in_cat,in_cont,classifier):
    #final features list
    L = []
    for feat_num in range(len(in_cat+in_cont)):
        if len(in_cat) != 0 and len(in_cont) != 0:
            # create a bunch of potential classifiers and establish a baseline performance for each
            clf_cat = classifier
            clf_cat.fit([[num] for num in train[in_cat[0]]], train['score'])
            clf_cont = classifier
            clf_cont.fit([[num] for num in train[in_cont[0]]], train['score'])
            acc_cat = clf_cat.score([[num] for num in test[in_cat[0]]],test['score'])
            acc_cont = clf_cont.score([[num] for num in test[in_cont[0]]],test['score'])
            if acc_cat < acc_cont:
                yield in_cont[0]
                in_cont = in_cont[1:]
            else:
                yield (in_cat[0])
                in_cat = in_cat[1:]
        else:
            if len(in_cat) == 0:
                yield (in_cont[0])
                in_cont = in_cont[1:]
            else:
                yield (in_cat[0])
                in_cat = in_cat[1:]
                
# final output of ranked features                
# list(filter_wrapper_featureselection(td['int64'],td['float64']))

# %%
# plot error rate versus number of features to determine, which is in this case exactly the number of wrong classifications, so we will just plot accuracy
import matplotlib.pyplot as plt
ranked_features_list =[ list(filter_wrapper_featureselection(td['int64'],td['float64'],cl)) for cl in potential_classifiers ]
acclst = []
optimum = []
for cl in potential_classifiers:
    best_model = cl
    classifier_acc = []
    rank = list(filter_wrapper_featureselection(td['int64'],td['float64'],cl))
    for ind,features in enumerate(rank):
        cl.fit(train[rank[:ind+1]], train['score'])
        acc = cl.score(test[rank[:ind+1]],test['score'])
        classifier_acc.append((ind+1,acc,cl))
        plt.figure()
    print cl
    plt.xlabel("Number of features selected")
    plt.ylabel("accuracy")
    plt.plot(range(1, len(rank) + 1), [accur[1] for accur in classifier_acc])
    plt.show()
    model_optimal_condition = max(classifier_acc, key=lambda accur: accur[1])
    optimum.append(model_optimal_condition)
print optimum
final_model = max(optimum, key=lambda maxacc: maxacc[1])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l1', random_state=None, tol=0.0001)
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=1,
#             random_state=0, splitter='best')
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=1, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0)
# ExtraTreesClassifier(bootstrap=False, compute_importances=None,
#            criterion='gini', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#            min_samples_split=1, n_estimators=10, n_jobs=1, oob_score=False,
#            random_state=0, verbose=0)
# GaussianNB()
# BernoulliNB(alpha=5.0, binarize=0.0, class_prior=None, fit_prior=True)
# [(21, 0.81413043478260871, LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l1', random_state=None, tol=0.0001)), (6, 0.78586956521739126, DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=1,
#             random_state=0, splitter='best')), (21, 0.83804347826086956, RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=1, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0)), (21, 0.82282608695652171, ExtraTreesClassifier(bootstrap=False, compute_importances=None,
#            criterion='gini', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#            min_samples_split=1, n_estimators=10, n_jobs=1, oob_score=False,
#            random_state=0, verbose=0)), (1, 0.80543478260869561, GaussianNB()), (19, 0.78260869565217395, BernoulliNB(alpha=5.0, binarize=0.0, class_prior=None, fit_prior=True))]

# %%
print "optimum number of features",final_model[0]
print "model with the highest score",final_model[2]
print "highest accuracy",final_model[1]
# after choosing the final model we will use the full training data and apply it to the test data given
# Out:
# optimum number of features 21
# model with the highest score RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=1, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0)
# highest accuracy 0.838043478261
